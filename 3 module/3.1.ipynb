# %% [markdown]
# linear regression

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
df = pd.DataFrame({
    'hours': [1, 2, 4, 5, 5, 6, 6, 7, 8, 10, 11, 11, 12, 12, 14],
     'score': [64, 66, 76, 73, 74, 81, 83, 82, 80, 88, 84, 82, 91, 93, 89]
})
y = df['score']
X = df[['hours']]
reg = LinearRegression()
reg.fit(X, y)
k = reg.coef_
b = reg.intercept_
# y = kx + b
plt.figure(figsize=(16,9))
plt.scatter(df['hours'], df['score'])
plt.title('Hours/Score')
plt.xlabel('Hours')
plt.ylabel('score')
plt.plot(X, k * X + b)
plt.show()
x_new = np.arange(4, 7).reshape((-1, 1))
print(x_new)
print(reg.predict(x_new))
# Out:
# [[4]
#  [5]
#  [6]]
# [73.26345083 75.2458256  77.22820037]
# C:\Users\Борис\PycharmProjects\Inno_ai\venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
df
# Out:
#     hours  score
# 0       1     64
# 1       2     66
# 2       4     76
# 3       5     73
# 4       5     74
# 5       6     81
# 6       6     83
# 7       7     82
# 8       8     80
# 9      10     88
# 10     11     84
# 11     11     82
# 12     12     91
# 13     12     93
# 14     14     89

# %%
df.columns
# Out:
# Index(['hours', 'score'], dtype='object')
